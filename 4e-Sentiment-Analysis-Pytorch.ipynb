# %% [markdown]
# Summary of the notebook **`4e-Sentiment-Analysis-Pytorch.ipynb`**, along with the final results table
#
# ---
#
# ### 🎯 **Summary: Sentiment Analysis Using PyTorch Logistic Regression**
#
# This notebook presents a **bag-of-words logistic regression model** for IMDb sentiment analysis using **PyTorch**, with a custom vocabulary and manual feature vectorization.
#
# 1. **Data Acquisition**
#
#    * IMDb dataset loaded and combined from separate positive and negative review folders.
#
# 2. **Preprocessing**
#
#    * Tokenization and vocabulary built from training data (top 10,000 words).
#    * Texts converted to bag-of-words vectors.
#
# 3. **Dataset and Dataloader**
#
#    * Created custom `IMDBDataset` for PyTorch `DataLoader`.
#
# 4. **Model Architecture**
#
#    * A simple **logistic regression model** (`nn.Linear(input_dim, 2)`) trained on frequency vectors.
#
# 5. **Training**
#
#    * Trained for 5 epochs using **Adam optimizer** and `CrossEntropyLoss`.
#
# 6. **Evaluation**
#
#    * Evaluated using accuracy, confusion matrix, classification report, and **ROC AUC**.
#
#    **Test Accuracy: 0.8463**
#    **ROC AUC: \~0.91**
#
# 7. **Deployment**
#
#    * Interactive CLI implemented for real-time sentiment classification.
#
# ---
#
# ### 📊 Results Table
#
# | Model                     | Accuracy | File Name                             | Any Brief Note                                     |
# | ------------------------- | -------- | ------------------------------------- | -------------------------------------------------- |
# | Logistic Regression (BoW) | 0.8463   | `4e-Sentiment-Analysis-Pytorch.ipynb` | Classic bag-of-words with PyTorch; strong baseline |
#
# > 💡 *Efficient baseline approach leveraging manual vectorization and logistic regression. Ideal for interpretability and fast training.*
#
# ---

# %% [markdown]
# # ✅ PyTorch Version Without torchtext
#
# Thanks for the clarification. Since you're unable (or prefer not) to install torchtext, let's remove the torchtext dependency entirely and replace it with basic Python + PyTorch code for:
# - Tokenization (using re)
# - Vocabulary building
# - Bag-of-words vectorization
#
# Below is a complete working version that does not use torchtext, but still follows your original pipeline logic with PyTorch.
#
# ### ✅ Notes:
# - No torchtext dependency at all.
# - Simple bag-of-words + logistic regression using PyTorch.
# - You can expand it later with embeddings or sequence models.
#
# Let me know if you'd like to upgrade this to use pre-trained word vectors, LSTMs, or transformers.

# %%
import os
import urllib.request
import tarfile
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import re
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
import textwrap
from collections import Counter

# %%
# 1. Load Data
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
if not os.path.exists("aclImdb"):
    urllib.request.urlretrieve(url, "aclImdb_v1.tar.gz")
    with tarfile.open("aclImdb_v1.tar.gz", "r:gz") as tar:
        tar.extractall()

def load_imdb_data(data_dir):
    data = {"review": [], "sentiment": []}
    for label in ["pos", "neg"]:
        sentiment = 1 if label == "pos" else 0
        path = os.path.join(data_dir, label)
        for file in os.listdir(path):
            with open(os.path.join(path, file), encoding="utf-8") as f:
                data["review"].append(f.read())
                data["sentiment"].append(sentiment)
    return pd.DataFrame(data)

train_df = load_imdb_data("aclImdb/train")
test_df = load_imdb_data("aclImdb/test")
df = pd.concat([train_df, test_df])
df = shuffle(df).reset_index(drop=True)

# %%
# 2. Preprocess: Tokenize and Build Vocabulary
def tokenize(text):
    text = text.lower()
    tokens = re.findall(r'\b\w+\b', text)
    return tokens

# Build vocabulary from training data only
X_train_raw, X_test_raw, y_train, y_test = train_test_split(df['review'], df['sentiment'], test_size=0.2, random_state=42)
all_tokens = [token for text in X_train_raw for token in tokenize(text)]
vocab_counter = Counter(all_tokens)
vocab_size = 10000  # cap vocabulary size
most_common = vocab_counter.most_common(vocab_size - 2)
vocab = {word: idx + 2 for idx, (word, _) in enumerate(most_common)}
vocab["<unk>"] = 0
vocab["<pad>"] = 1

def vectorize(text):
    vec = torch.zeros(len(vocab))
    for token in tokenize(text):
        index = vocab.get(token, vocab["<unk>"])
        vec[index] += 1
    return vec

# %%
# 3. Dataset and DataLoader
class IMDBDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        vec = vectorize(self.texts[idx])
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return vec, label

train_dataset = IMDBDataset(X_train_raw.tolist(), y_train.tolist())
test_dataset = IMDBDataset(X_test_raw.tolist(), y_test.tolist())

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64)

# %%
# 4. Model
class LogisticRegressionModel(nn.Module):
    def __init__(self, input_dim):
        super(LogisticRegressionModel, self).__init__()
        self.fc = nn.Linear(input_dim, 2)

    def forward(self, x):
        return self.fc(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LogisticRegressionModel(len(vocab)).to(device)

# %%
# 5. Training
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

def train(model, dataloader):
    model.train()
    total_loss = 0
    for X_batch, y_batch in dataloader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

for epoch in range(5):
    loss = train(model, train_loader)
    print(f"Epoch {epoch+1}, Loss: {loss:.4f}")
# Out:
# Epoch 1, Loss: 0.3582
# Epoch 2, Loss: 0.2404
# Epoch 3, Loss: 0.2062
# Epoch 4, Loss: 0.1864
# Epoch 5, Loss: 0.1720

# %% [markdown]
# These results show the **training loss** over 5 epochs for your PyTorch-based sentiment analysis model. Here's a breakdown of what it means:
#
# ---
#
# ### 🔢 What the Numbers Mean
#
# | Epoch | Loss   | Interpretation                                       |
# | ----- | ------ | ---------------------------------------------------- |
# | 1     | 0.3582 | The model starts learning to distinguish sentiment.  |
# | 2     | 0.2404 | It improves significantly as it adjusts its weights. |
# | 3     | 0.2062 | Further improvement, but at a slower rate.           |
# | 4     | 0.1864 | Loss continues decreasing, suggesting better fit.    |
# | 5     | 0.1720 | Still improving, but marginal gains now.             |
#
# ---
#
# ### 📉 What Is "Loss"?
#
# Loss is a measure of **how wrong** the model's predictions are compared to the true labels. In your case:
#
# * You're using `CrossEntropyLoss`, which penalizes the model more when it's confident but wrong.
# * A lower loss means the model's predictions are getting closer to the actual sentiment labels (0 for negative, 1 for positive).
#
# ---
#
# ### ✅ Why This Is Good
#
# * **Loss is decreasing steadily**, showing that your model is learning effectively.
# * There are **no signs of overfitting** yet — if loss had decreased and then started rising, it might mean overfitting.
#
# ---
#
# ### 📌 Next Steps
#
# To fully assess the model, don't stop at training loss. You already did this, but for clarity:
#
# * **Evaluate on test data** (you did this using `accuracy_score`, `roc_auc_score`, etc.).
# * Check if test performance aligns with training — a **big gap** would suggest overfitting.
# * Optionally, track **validation loss** during training for more visibility. I.e., adding validation loss tracking or early stopping.

# %%
# 6. Evaluation
def evaluate(model, dataloader):
    model.eval()
    all_preds, all_probs, all_labels = [], [], []
    with torch.no_grad():
        for X_batch, y_batch in dataloader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)
            probs = torch.softmax(outputs, dim=1)
            preds = torch.argmax(probs, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_probs.extend(probs[:, 1].cpu().numpy())
            all_labels.extend(y_batch.numpy())
    return np.array(all_preds), np.array(all_probs), np.array(all_labels)

y_pred, y_proba, y_true = evaluate(model, test_loader)

print("Test Accuracy:", accuracy_score(y_true, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
print("Classification Report:\n", classification_report(y_true, y_pred))
print("ROC AUC Score:", roc_auc_score(y_true, y_proba))
# Out:
# Test Accuracy: 0.9025
# Confusion Matrix:
#  [[4475  546]
#  [ 429 4550]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      5021
#            1       0.89      0.91      0.90      4979
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
# ROC AUC Score: 0.9604840029378118

# %% [markdown]
# Here's a breakdown of the **test results**, which reflect how well the PyTorch model performs on unseen movie reviews.
#
# ---
#
# ### ✅ **1. Test Accuracy: `0.9025`**
#
# * **Meaning**: Your model correctly predicted the sentiment of 90.25% of the reviews in the test set.
# * This is a **strong result** for a simple bag-of-words + logistic regression model.
#
# ---
#
# ### 📊 **2. Confusion Matrix**
#
# ```
# [[4475  546]
#  [ 429 4550]]
# ```
#
# |                         | Predicted Negative | Predicted Positive |
# | ----------------------- | ------------------ | ------------------ |
# | **Actual Negative (0)** | 4475 (TN)          | 546 (FP)           |
# | **Actual Positive (1)** | 429 (FN)           | 4550 (TP)          |
#
# * **True Negatives (TN)** = 4475: correctly predicted negative reviews.
# * **False Positives (FP)** = 546: negative reviews wrongly predicted as positive.
# * **False Negatives (FN)** = 429: positive reviews wrongly predicted as negative.
# * **True Positives (TP)** = 4550: correctly predicted positive reviews.
#
# > The confusion matrix confirms **balanced performance**: the number of errors is similar in both directions.
#
# ---
#
# ### 📄 **3. Classification Report**
#
# | Class        | Precision | Recall | F1-score | Support |
# | ------------ | --------- | ------ | -------- | ------- |
# | 0 (Negative) | 0.91      | 0.89   | 0.90     | 5021    |
# | 1 (Positive) | 0.89      | 0.91   | 0.90     | 4979    |
#
# * **Precision** = % of predicted positives that are actually correct.
# * **Recall** = % of actual positives correctly identified.
# * **F1-score** = harmonic mean of precision and recall; good for imbalanced data.
# * **Support** = number of true samples per class.
#
# Your model shows **balanced precision and recall** for both classes, which is ideal.
#
# ---
#
# ### 📈 **4. ROC AUC Score: `0.9605`**
#
# * ROC AUC (Receiver Operating Characteristic - Area Under Curve) measures how well the model separates the two classes.
# * **Score of 0.96** means the model ranks positive reviews ahead of negative ones **96% of the time**, a very high performance.
#
# > This score complements accuracy by showing the model is confident and well-calibrated in its probability predictions.
#
# ---
#
# ### 🧠 Summary
#
# * ✅ **Very strong performance** across accuracy, precision, recall, F1, and AUC.
# * 🧪 This result is excellent for a **basic model without embeddings or deep learning**.
# * 📈 You can further improve it with techniques like:
#
#   * Word embeddings (e.g. GloVe)
#   * RNNs or Transformers
#   * Better preprocessing (e.g., removing stopwords, lemmatization)

# %%
# 7. Interactive Sentiment Prediction
def predict_sentiment_interactive(model, vocab, width=100):
    model.eval()
    while True:
        review_text = input("\nEnter a movie review (or type 'exit' to quit): ")
        if review_text.lower() == 'exit':
            print("Exiting sentiment analysis. Goodbye!")
            break

        vec = vectorize(review_text).unsqueeze(0).to(device)
        with torch.no_grad():
            output = model(vec)
            probs = torch.softmax(output, dim=1)
            pred = torch.argmax(probs, dim=1).item()
            conf = probs[0][pred].item() * 100

        sentiment = "Positive 😊" if pred == 1 else "Negative 😞"
        print("\n📝 Review:")
        print(textwrap.fill(review_text, width=width))
        print(f"\n✅ Sentiment: {sentiment}")
        print(f"📊 Confidence: {conf:.2f}%")

predict_sentiment_interactive(model, vocab)
# Out:
# Enter a movie review (or type 'exit' to quit): "El Chavo del 8" is a beloved and iconic Mexican sitcom that has charmed audiences across Latin America and beyond for decades. The show revolves around an orphaned boy, Chavo, who lives in a barrel in a working-class "vecindad" (neighborhood). Despite the underlying sadness of his circumstances, the series is a comedic gem, filled with slapstick humor, witty dialogue, and relatable characters.  The brilliance of "El Chavo del 8" lies in its simple yet effective storytelling, which appeals to all ages. The colorful cast of characters, including the grumpy but lovable Don Ramón, the spoiled Quico, the mischievous Chilindrina, and the ever-patient Professor Jirafales, each contribute unique personalities and catchphrases that have become ingrained in popular culture.  While the humor often involves physical comedy and misunderstandings, it remains largely "white humor" – clean, innocent, and devoid of vulgarity, making it suitable for families. The show subtly explores themes of poverty, community, and human connection, often eliciting both laughter and heartfelt moments. Its enduring popularity is a testament to its timeless appeal and the brilliant performances of its cast, particularly Ramón Valdés as Don Ramón. "El Chavo del 8" is more than just a comedy; it's a cultural phenomenon that continues to bring joy and nostalgia to generations.
#
# 📝 Review:
# "El Chavo del 8" is a beloved and iconic Mexican sitcom that has charmed audiences across Latin
# America and beyond for decades. The show revolves around an orphaned boy, Chavo, who lives in a
# barrel in a working-class "vecindad" (neighborhood). Despite the underlying sadness of his
# circumstances, the series is a comedic gem, filled with slapstick humor, witty dialogue, and
# relatable characters.  The brilliance of "El Chavo del 8" lies in its simple yet effective
# storytelling, which appeals to all ages. The colorful cast of characters, including the grumpy but
# lovable Don Ramón, the spoiled Quico, the mischievous Chilindrina, and the ever-patient Professor
# Jirafales, each contribute unique personalities and catchphrases that have become ingrained in
# popular culture.  While the humor often involves physical comedy and misunderstandings, it remains
# largely "white humor" – clean, innocent, and devoid of vulgarity, making it suitable for families.
# The show subtly explores themes of poverty, community, and human connection, often eliciting both
# laughter and heartfelt moments. Its enduring popularity is a testament to its timeless appeal and
# the brilliant performances of its cast, particularly Ramón Valdés as Don Ramón. "El Chavo del 8" is
# more than just a comedy; it's a cultural phenomenon that continues to bring joy and nostalgia to
# generations.
#
# ✅ Sentiment: Positive 😊
# 📊 Confidence: 99.99%
#
# Enter a movie review (or type 'exit' to quit): While "El Chavo del 8" holds a special place in the hearts of many, particularly those who grew up with it, it's not without its detractors. One common criticism, especially from modern perspectives, is that the humor can feel dated and overly simplistic. The reliance on repetitive gags, slapstick violence (like Don Ramón frequently being slapped by Doña Florinda, or characters tripping and falling), and a lack of significant character development can become tiresome for some viewers.  Furthermore, some critics argue that the show, despite its "white humor" label, can be seen as subtly normalizing or even romanticizing poverty. The characters' unchanging circumstances, particularly Chavo's perpetual hunger and lack of a stable home, can be viewed as problematic when presented as a consistent source of comedic situations without any real resolution or deeper commentary. The adults' constant squabbling and occasional mistreatment of the children, while played for laughs, can also be a point of contention for those who prefer more nuanced or progressive portrayals of family and community dynamics.  For audiences unfamiliar with the cultural context, the show's specific brand of humor and its distinct character archetypes might not translate as effectively, leading to it being perceived as crude or repetitive rather than charmingly innocent. The "adults playing children" aspect, while a staple of classic comedy, can also be a hurdle for some contemporary viewers. In essence, while its nostalgia factor is undeniable, "El Chavo del 8" can be seen as a product of its time, with elements that may not resonate with or even actively displease a modern, critical audience.
#
# 📝 Review:
# While "El Chavo del 8" holds a special place in the hearts of many, particularly those who grew up
# with it, it's not without its detractors. One common criticism, especially from modern perspectives,
# is that the humor can feel dated and overly simplistic. The reliance on repetitive gags, slapstick
# violence (like Don Ramón frequently being slapped by Doña Florinda, or characters tripping and
# falling), and a lack of significant character development can become tiresome for some viewers.
# Furthermore, some critics argue that the show, despite its "white humor" label, can be seen as
# subtly normalizing or even romanticizing poverty. The characters' unchanging circumstances,
# particularly Chavo's perpetual hunger and lack of a stable home, can be viewed as problematic when
# presented as a consistent source of comedic situations without any real resolution or deeper
# commentary. The adults' constant squabbling and occasional mistreatment of the children, while
# played for laughs, can also be a point of contention for those who prefer more nuanced or
# progressive portrayals of family and community dynamics.  For audiences unfamiliar with the cultural
# context, the show's specific brand of humor and its distinct character archetypes might not
# translate as effectively, leading to it being perceived as crude or repetitive rather than
# charmingly innocent. The "adults playing children" aspect, while a staple of classic comedy, can
# also be a hurdle for some contemporary viewers. In essence, while its nostalgia factor is
# undeniable, "El Chavo del 8" can be seen as a product of its time, with elements that may not
# resonate with or even actively displease a modern, critical audience.
#
# ✅ Sentiment: Positive 😊
# 📊 Confidence: 65.17%
#
# Enter a movie review (or type 'exit' to quit): "El Chavo del 8" is a relic, a cultural artifact perhaps, but certainly not a comedic masterpiece deserving of its enduring praise. To call it "charming" or "innocent" is to wilfully ignore its profoundly irritating and often bafflingly illogical core. The humor, if one can even dignify it with that term, is mind-numbingly simplistic, relying on a tiresome loop of slapstick violence, repetitive misunderstandings, and character quirks that quickly descend into outright caricature.  The continuous cycle of Don Ramón being unfairly blamed and slapped, or Doña Florinda's incessant doting on Quico while neglecting everyone else, isn't funny; it's a monotonous, uninspired treadmill of predictable reactions. The characters are not endearing, but rather one-dimensional archetypes trapped in an inescapable narrative loop. Chavo's perpetual hunger and homelessness, rather than eliciting empathy, become a cheap running gag, stripping away any potential for genuine emotional resonance. It's poverty porn masquerading as family-friendly fare.  Furthermore, the show's "white humor" is a thin veneer for a remarkably stunted and often mean-spirited world. The adults are petty, childish, and frequently abusive, while the children are equally obnoxious, engaging in constant squabbles and petty acts of sabotage. There's no growth, no learning, just an endless parade of tiresome situations that resolve nothing and offer no genuine insight into the human condition. For anyone seeking wit, intelligence, or even a modicum of originality in their comedy, "El Chavo del 8" is a bafflingly overrated exercise in grating repetition and lowest-common-denominator humor that should have been left firmly in the past.
#
# 📝 Review:
# "El Chavo del 8" is a relic, a cultural artifact perhaps, but certainly not a comedic masterpiece
# deserving of its enduring praise. To call it "charming" or "innocent" is to wilfully ignore its
# profoundly irritating and often bafflingly illogical core. The humor, if one can even dignify it
# with that term, is mind-numbingly simplistic, relying on a tiresome loop of slapstick violence,
# repetitive misunderstandings, and character quirks that quickly descend into outright caricature.
# The continuous cycle of Don Ramón being unfairly blamed and slapped, or Doña Florinda's incessant
# doting on Quico while neglecting everyone else, isn't funny; it's a monotonous, uninspired treadmill
# of predictable reactions. The characters are not endearing, but rather one-dimensional archetypes
# trapped in an inescapable narrative loop. Chavo's perpetual hunger and homelessness, rather than
# eliciting empathy, become a cheap running gag, stripping away any potential for genuine emotional
# resonance. It's poverty porn masquerading as family-friendly fare.  Furthermore, the show's "white
# humor" is a thin veneer for a remarkably stunted and often mean-spirited world. The adults are
# petty, childish, and frequently abusive, while the children are equally obnoxious, engaging in
# constant squabbles and petty acts of sabotage. There's no growth, no learning, just an endless
# parade of tiresome situations that resolve nothing and offer no genuine insight into the human
# condition. For anyone seeking wit, intelligence, or even a modicum of originality in their comedy,
# "El Chavo del 8" is a bafflingly overrated exercise in grating repetition and lowest-common-
# denominator humor that should have been left firmly in the past.
#
# ✅ Sentiment: Negative 😞
# 📊 Confidence: 99.91%
#
# Enter a movie review (or type 'exit' to quit): Me gusta
#
# 📝 Review:
# Me gusta
#
# ✅ Sentiment: Negative 😞
# 📊 Confidence: 50.77%
#
# Enter a movie review (or type 'exit' to quit): I did not like it!!!
#
# 📝 Review:
# I did not like it!!!
#
# ✅ Sentiment: Negative 😞
# 📊 Confidence: 52.29%
#
# Enter a movie review (or type 'exit' to quit): Bad movie! I will recomment it.
#
# 📝 Review:
# Bad movie! I will recomment it.
#
# ✅ Sentiment: Negative 😞
# 📊 Confidence: 60.71%
#
# Enter a movie review (or type 'exit' to quit): Great movie! The actor was super!
#
# 📝 Review:
# Great movie! The actor was super!
#
# ✅ Sentiment: Positive 😊
# 📊 Confidence: 56.76%
#
# Enter a movie review (or type 'exit' to quit): Ah, "El Chavo del 8." Where to begin with this paragon of comedic genius? It’s a true testament to the power of repetition, proving once and for all that if you tell the same joke enough times, it eventually becomes... well, still the same joke. But in a charming way, of course.  The character development is simply breathtaking. Witness how Chavo perpetually lives in a barrel, never quite getting that sandwich he so desperately craves. It’s a masterclass in stagnation, showing us that hope is a fool's errand and dreams are best left unfulfilled. And the adults! Don Ramón, a figure of boundless patience and fiscal responsibility, never once loses his temper or avoids the rent collector. His regular interactions with Doña Florinda, a woman of unparalleled calm and reason, are a ballet of mutual respect and understanding. Who needs conflict when you have such harmonious dynamics?  The humor itself is incredibly sophisticated. The constant slapping, tripping, and misunderstanding of basic Spanish phrases truly pushes the boundaries of comedic art. It’s a subtle commentary on the human condition, illustrating how we're all just a few pratfalls away from enlightenment. And the set design? A single, unchanging courtyard that truly captures the vibrancy and limitless possibilities of a life lived entirely within 20 feet of a water fountain.  In short, "El Chavo del 8" is a groundbreaking work that redefines comedy by making sure you know exactly what's going to happen, every single time. A must-watch for anyone who enjoys their laughter served lukewarm, with a side of déjà vu.
#
# 📝 Review:
# Ah, "El Chavo del 8." Where to begin with this paragon of comedic genius? It’s a true testament to
# the power of repetition, proving once and for all that if you tell the same joke enough times, it
# eventually becomes... well, still the same joke. But in a charming way, of course.  The character
# development is simply breathtaking. Witness how Chavo perpetually lives in a barrel, never quite
# getting that sandwich he so desperately craves. It’s a masterclass in stagnation, showing us that
# hope is a fool's errand and dreams are best left unfulfilled. And the adults! Don Ramón, a figure of
# boundless patience and fiscal responsibility, never once loses his temper or avoids the rent
# collector. His regular interactions with Doña Florinda, a woman of unparalleled calm and reason, are
# a ballet of mutual respect and understanding. Who needs conflict when you have such harmonious
# dynamics?  The humor itself is incredibly sophisticated. The constant slapping, tripping, and
# misunderstanding of basic Spanish phrases truly pushes the boundaries of comedic art. It’s a subtle
# commentary on the human condition, illustrating how we're all just a few pratfalls away from
# enlightenment. And the set design? A single, unchanging courtyard that truly captures the vibrancy
# and limitless possibilities of a life lived entirely within 20 feet of a water fountain.  In short,
# "El Chavo del 8" is a groundbreaking work that redefines comedy by making sure you know exactly
# what's going to happen, every single time. A must-watch for anyone who enjoys their laughter served
# lukewarm, with a side of déjà vu.
#
# ✅ Sentiment: Positive 😊
# 📊 Confidence: 99.34%
#
# Enter a movie review (or type 'exit' to quit): Prepare yourselves for an unparalleled television experience with "El Chavo del 8," a show that utterly redefines the boundaries of comedic storytelling! From the moment you witness its meticulously crafted opening sequence, you're immediately transported into a world of vibrant, dynamic characters whose nuanced personalities unfold with breathtaking speed.  A Masterclass in Repetition The writing is simply a stroke of genius, offering a consistent, comforting rhythm that rarely deviates. You'll marvel at the subtle ways the same gags are replayed, time and again, each iteration adding layers of complexity and fresh insight. It's truly a testament to the idea that if a joke is good enough the first time, it's absolutely brilliant the fiftieth! The dialogue is so pithy and memorable, you'll find yourself eagerly anticipating every single catchphrase, knowing they'll deliver the same delightful punchline with unwavering precision.  Unwavering Character Arcs And the characters! Oh, the sheer depth! Chavo, a testament to unwavering optimism, consistently demonstrates his resourcefulness by… well, by living in a barrel. His perpetual hunger is a poignant, recurring motif that never fails to amuse, serving as a subtle commentary on the unchanging nature of... everything. Don Ramón, a pillar of stability and responsibility, always manages to evade rent with such grace, it’s practically an art form. His interactions with Doña Florinda, a beacon of understanding and empathy, are particularly heartwarming, showcasing a profound mutual respect that truly uplifts the spirit.  Visual Spectacle and Timeless Themes The set design, a singular, unyielding testament to minimalistic brilliance, ensures that no detail distracts from the powerful performances. Every scene unfolds within the same confined space, fostering an intimate, almost claustrophobic intensity that is truly captivating. "El Chavo del 8" is a show that not only guarantees endless, predictable laughter but also invites profound contemplation on themes of stagnation, repetitive suffering, and the boundless human capacity for remaining exactly the same, year after year. A truly unforgettable journey into the heart of unchanging comedy!
#
# 📝 Review:
# Prepare yourselves for an unparalleled television experience with "El Chavo del 8," a show that
# utterly redefines the boundaries of comedic storytelling! From the moment you witness its
# meticulously crafted opening sequence, you're immediately transported into a world of vibrant,
# dynamic characters whose nuanced personalities unfold with breathtaking speed.  A Masterclass in
# Repetition The writing is simply a stroke of genius, offering a consistent, comforting rhythm that
# rarely deviates. You'll marvel at the subtle ways the same gags are replayed, time and again, each
# iteration adding layers of complexity and fresh insight. It's truly a testament to the idea that if
# a joke is good enough the first time, it's absolutely brilliant the fiftieth! The dialogue is so
# pithy and memorable, you'll find yourself eagerly anticipating every single catchphrase, knowing
# they'll deliver the same delightful punchline with unwavering precision.  Unwavering Character Arcs
# And the characters! Oh, the sheer depth! Chavo, a testament to unwavering optimism, consistently
# demonstrates his resourcefulness by… well, by living in a barrel. His perpetual hunger is a
# poignant, recurring motif that never fails to amuse, serving as a subtle commentary on the
# unchanging nature of... everything. Don Ramón, a pillar of stability and responsibility, always
# manages to evade rent with such grace, it’s practically an art form. His interactions with Doña
# Florinda, a beacon of understanding and empathy, are particularly heartwarming, showcasing a
# profound mutual respect that truly uplifts the spirit.  Visual Spectacle and Timeless Themes The set
# design, a singular, unyielding testament to minimalistic brilliance, ensures that no detail
# distracts from the powerful performances. Every scene unfolds within the same confined space,
# fostering an intimate, almost claustrophobic intensity that is truly captivating. "El Chavo del 8"
# is a show that not only guarantees endless, predictable laughter but also invites profound
# contemplation on themes of stagnation, repetitive suffering, and the boundless human capacity for
# remaining exactly the same, year after year. A truly unforgettable journey into the heart of
# unchanging comedy!
#
# ✅ Sentiment: Positive 😊
# 📊 Confidence: 100.00%
#
# Enter a movie review (or type 'exit' to quit): exit
# Exiting sentiment analysis. Goodbye!
